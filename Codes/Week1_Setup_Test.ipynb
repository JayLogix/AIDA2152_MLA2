# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import LabelEncoder

print("pandas:", pd.__version__)
print("numpy:", np.__version__)
print("MLA2 setup works")
# Out:
# pandas: 3.0.5
# numpy: 2.5.3
# MLA2 setup works
